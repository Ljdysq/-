# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels=1,  # 输入通道数（MNIST 是灰度图像，通道数为 1）
                out_channels=32,  # 输出通道数
                kernel_size=7,  # 卷积核大小 7x7
                stride=1,  # 步幅
                padding=3,  # 填充值，计算方式：(kernel_size - 1) // 2
            ),
            nn.ReLU(),  # 激活函数
            nn.MaxPool2d(2),  # 池化操作，池化核大小为 2x2
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(
                in_channels=32,  # 输入通道数
                out_channels=64,  # 输出通道数
                kernel_size=5,  # 卷积核大小 5x5
                stride=1,  # 步幅
                padding=2,  # 填充值，计算方式：(kernel_size - 1) // 2
            ),
            nn.ReLU(),  # 激活函数
            nn.MaxPool2d(2),  # 池化操作，池化核大小为 2x2
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)  # 展平为 (batch_size, 7*7*64)
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST\raw\train-images-idx3-ubyte.gz
# 100.0%
# Extracting ./mnist/MNIST\raw\train-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz
# 100.0%
# Extracting ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz
# 100.0%
# Extracting ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100.0%
# c:\Users\86139\anaconda3\envs\ND\Lib\site-packages\torchvision\datasets\mnist.py:81: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\86139\AppData\Local\Temp\ipykernel_20648\309666441.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# c:\Users\86139\anaconda3\envs\ND\Lib\site-packages\torchvision\datasets\mnist.py:71: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# C:\Users\86139\AppData\Local\Temp\ipykernel_20648\309666441.py:67: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# Extracting ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# ========== 20 ===== ===== test accuracy is  0.278 ==========
# ========== 40 ===== ===== test accuracy is  0.39 ==========
# ========== 60 ===== ===== test accuracy is  0.45 ==========
# ========== 80 ===== ===== test accuracy is  0.58 ==========
# ========== 100 ===== ===== test accuracy is  0.628 ==========
# ========== 120 ===== ===== test accuracy is  0.648 ==========
# ========== 140 ===== ===== test accuracy is  0.712 ==========
# ========== 160 ===== ===== test accuracy is  0.698 ==========
# ========== 180 ===== ===== test accuracy is  0.73 ==========
# ========== 200 ===== ===== test accuracy is  0.752 ==========
# ========== 220 ===== ===== test accuracy is  0.782 ==========
# ========== 240 ===== ===== test accuracy is  0.752 ==========
# ========== 260 ===== ===== test accuracy is  0.798 ==========
# ========== 280 ===== ===== test accuracy is  0.816 ==========
# ========== 300 ===== ===== test accuracy is  0.826 ==========
# ========== 320 ===== ===== test accuracy is  0.846 ==========
# ========== 340 ===== ===== test accuracy is  0.838 ==========
# ========== 360 ===== ===== test accuracy is  0.872 ==========
# ========== 380 ===== ===== test accuracy is  0.88 ==========
# ========== 400 ===== ===== test accuracy is  0.888 ==========
# ========== 420 ===== ===== test accuracy is  0.864 ==========
# ========== 440 ===== ===== test accuracy is  0.874 ==========
# ========== 460 ===== ===== test accuracy is  0.898 ==========
# ========== 480 ===== ===== test accuracy is  0.892 ==========
# ========== 500 ===== ===== test accuracy is  0.892 ==========
# ========== 520 ===== ===== test accuracy is  0.892 ==========
# ========== 540 ===== ===== test accuracy is  0.902 ==========
# ========== 560 ===== ===== test accuracy is  0.924 ==========
# ========== 580 ===== ===== test accuracy is  0.906 ==========
# ========== 600 ===== ===== test accuracy is  0.91 ==========
# ========== 620 ===== ===== test accuracy is  0.92 ==========
# ========== 640 ===== ===== test accuracy is  0.93 ==========
# ========== 660 ===== ===== test accuracy is  0.914 ==========
# ========== 680 ===== ===== test accuracy is  0.908 ==========
# ========== 700 ===== ===== test accuracy is  0.922 ==========
# ========== 720 ===== ===== test accuracy is  0.912 ==========
# ========== 740 ===== ===== test accuracy is  0.922 ==========
# ========== 760 ===== ===== test accuracy is  0.924 ==========
# ========== 780 ===== ===== test accuracy is  0.924 ==========
# ========== 800 ===== ===== test accuracy is  0.922 ==========
# ========== 820 ===== ===== test accuracy is  0.938 ==========
# ========== 840 ===== ===== test accuracy is  0.932 ==========
# ========== 860 ===== ===== test accuracy is  0.942 ==========
# ========== 880 ===== ===== test accuracy is  0.94 ==========
# ========== 900 ===== ===== test accuracy is  0.926 ==========
# ========== 920 ===== ===== test accuracy is  0.934 ==========
# ========== 940 ===== ===== test accuracy is  0.942 ==========
# ========== 960 ===== ===== test accuracy is  0.942 ==========
# ========== 980 ===== ===== test accuracy is  0.944 ==========
# ========== 1000 ===== ===== test accuracy is  0.944 ==========
# ========== 1020 ===== ===== test accuracy is  0.946 ==========
# ========== 1040 ===== ===== test accuracy is  0.952 ==========
# ========== 1060 ===== ===== test accuracy is  0.942 ==========
# ========== 1080 ===== ===== test accuracy is  0.938 ==========
# ========== 1100 ===== ===== test accuracy is  0.956 ==========
# ========== 1120 ===== ===== test accuracy is  0.936 ==========
# ========== 1140 ===== ===== test accuracy is  0.936 ==========
# ========== 1160 ===== ===== test accuracy is  0.942 ==========
# ========== 1180 ===== ===== test accuracy is  0.934 ==========
# ========== 20 ===== ===== test accuracy is  0.942 ==========
# ========== 40 ===== ===== test accuracy is  0.94 ==========
# ========== 60 ===== ===== test accuracy is  0.956 ==========
# ========== 80 ===== ===== test accuracy is  0.954 ==========
# ========== 100 ===== ===== test accuracy is  0.962 ==========
# ========== 120 ===== ===== test accuracy is  0.948 ==========
# ========== 140 ===== ===== test accuracy is  0.942 ==========
# ========== 160 ===== ===== test accuracy is  0.958 ==========
# ========== 180 ===== ===== test accuracy is  0.946 ==========
# ========== 200 ===== ===== test accuracy is  0.964 ==========
# ========== 220 ===== ===== test accuracy is  0.964 ==========
# ========== 240 ===== ===== test accuracy is  0.96 ==========
# ========== 260 ===== ===== test accuracy is  0.94 ==========
# ========== 280 ===== ===== test accuracy is  0.952 ==========
# ========== 300 ===== ===== test accuracy is  0.96 ==========
# ========== 320 ===== ===== test accuracy is  0.962 ==========
# ========== 340 ===== ===== test accuracy is  0.958 ==========
# ========== 360 ===== ===== test accuracy is  0.97 ==========
# ========== 380 ===== ===== test accuracy is  0.956 ==========
# ========== 400 ===== ===== test accuracy is  0.962 ==========
# ========== 420 ===== ===== test accuracy is  0.97 ==========
# ========== 440 ===== ===== test accuracy is  0.954 ==========
# ========== 460 ===== ===== test accuracy is  0.962 ==========
# ========== 480 ===== ===== test accuracy is  0.954 ==========
# ========== 500 ===== ===== test accuracy is  0.97 ==========
# ========== 520 ===== ===== test accuracy is  0.968 ==========
# ========== 540 ===== ===== test accuracy is  0.968 ==========
# ========== 560 ===== ===== test accuracy is  0.964 ==========
# ========== 580 ===== ===== test accuracy is  0.96 ==========
# ========== 600 ===== ===== test accuracy is  0.964 ==========
# ========== 620 ===== ===== test accuracy is  0.97 ==========
# ========== 640 ===== ===== test accuracy is  0.964 ==========
# ========== 660 ===== ===== test accuracy is  0.976 ==========
# ========== 680 ===== ===== test accuracy is  0.962 ==========
# ========== 700 ===== ===== test accuracy is  0.96 ==========
# ========== 720 ===== ===== test accuracy is  0.962 ==========
# ========== 740 ===== ===== test accuracy is  0.964 ==========
# ========== 760 ===== ===== test accuracy is  0.97 ==========
# ========== 780 ===== ===== test accuracy is  0.976 ==========
# ========== 800 ===== ===== test accuracy is  0.962 ==========
# ========== 820 ===== ===== test accuracy is  0.966 ==========
# ========== 840 ===== ===== test accuracy is  0.954 ==========
# ========== 860 ===== ===== test accuracy is  0.966 ==========
# ========== 880 ===== ===== test accuracy is  0.97 ==========
# ========== 900 ===== ===== test accuracy is  0.97 ==========
# ========== 920 ===== ===== test accuracy is  0.966 ==========
# ========== 940 ===== ===== test accuracy is  0.966 ==========
# ========== 960 ===== ===== test accuracy is  0.974 ==========
# ========== 980 ===== ===== test accuracy is  0.972 ==========
# ========== 1000 ===== ===== test accuracy is  0.97 ==========
# ========== 1020 ===== ===== test accuracy is  0.964 ==========
# ========== 1040 ===== ===== test accuracy is  0.974 ==========
# ========== 1060 ===== ===== test accuracy is  0.966 ==========
# ========== 1080 ===== ===== test accuracy is  0.966 ==========
# ========== 1100 ===== ===== test accuracy is  0.966 ==========
# ========== 1120 ===== ===== test accuracy is  0.972 ==========
# ========== 1140 ===== ===== test accuracy is  0.966 ==========
# ========== 1160 ===== ===== test accuracy is  0.97 ==========
# ========== 1180 ===== ===== test accuracy is  0.968 ==========
# ========== 20 ===== ===== test accuracy is  0.962 ==========
# ========== 40 ===== ===== test accuracy is  0.97 ==========
# ========== 60 ===== ===== test accuracy is  0.972 ==========
# ========== 80 ===== ===== test accuracy is  0.974 ==========
# ========== 100 ===== ===== test accuracy is  0.97 ==========
# ========== 120 ===== ===== test accuracy is  0.972 ==========
# ========== 140 ===== ===== test accuracy is  0.972 ==========
# ========== 160 ===== ===== test accuracy is  0.97 ==========
# ========== 180 ===== ===== test accuracy is  0.97 ==========
# ========== 200 ===== ===== test accuracy is  0.968 ==========
# ========== 220 ===== ===== test accuracy is  0.972 ==========
# ========== 240 ===== ===== test accuracy is  0.974 ==========
# ========== 260 ===== ===== test accuracy is  0.974 ==========
# ========== 280 ===== ===== test accuracy is  0.972 ==========
# ========== 300 ===== ===== test accuracy is  0.97 ==========
# ========== 320 ===== ===== test accuracy is  0.97 ==========
# ========== 340 ===== ===== test accuracy is  0.966 ==========
# ========== 360 ===== ===== test accuracy is  0.97 ==========
# ========== 380 ===== ===== test accuracy is  0.97 ==========
# ========== 400 ===== ===== test accuracy is  0.97 ==========
# ========== 420 ===== ===== test accuracy is  0.974 ==========
# ========== 440 ===== ===== test accuracy is  0.968 ==========
# ========== 460 ===== ===== test accuracy is  0.972 ==========
# ========== 480 ===== ===== test accuracy is  0.974 ==========
# ========== 500 ===== ===== test accuracy is  0.97 ==========
# ========== 520 ===== ===== test accuracy is  0.972 ==========
# ========== 540 ===== ===== test accuracy is  0.968 ==========
# ========== 560 ===== ===== test accuracy is  0.98 ==========
# ========== 580 ===== ===== test accuracy is  0.976 ==========
# ========== 600 ===== ===== test accuracy is  0.982 ==========
# ========== 620 ===== ===== test accuracy is  0.972 ==========
# ========== 640 ===== ===== test accuracy is  0.98 ==========
# ========== 660 ===== ===== test accuracy is  0.968 ==========
# ========== 680 ===== ===== test accuracy is  0.974 ==========
# ========== 700 ===== ===== test accuracy is  0.974 ==========
# ========== 720 ===== ===== test accuracy is  0.98 ==========
# ========== 740 ===== ===== test accuracy is  0.972 ==========
# ========== 760 ===== ===== test accuracy is  0.97 ==========
# ========== 780 ===== ===== test accuracy is  0.976 ==========
# ========== 800 ===== ===== test accuracy is  0.976 ==========
# ========== 820 ===== ===== test accuracy is  0.97 ==========
# ========== 840 ===== ===== test accuracy is  0.972 ==========
# ========== 860 ===== ===== test accuracy is  0.97 ==========
# ========== 880 ===== ===== test accuracy is  0.972 ==========
# ========== 900 ===== ===== test accuracy is  0.974 ==========
# ========== 920 ===== ===== test accuracy is  0.98 ==========
# ========== 940 ===== ===== test accuracy is  0.976 ==========
# ========== 960 ===== ===== test accuracy is  0.98 ==========
# ========== 980 ===== ===== test accuracy is  0.976 ==========
# ========== 1000 ===== ===== test accuracy is  0.97 ==========
# ========== 1020 ===== ===== test accuracy is  0.98 ==========
# ========== 1040 ===== ===== test accuracy is  0.974 ==========
# ========== 1060 ===== ===== test accuracy is  0.98 ==========
# ========== 1080 ===== ===== test accuracy is  0.974 ==========
# ========== 1100 ===== ===== test accuracy is  0.98 ==========
# ========== 1120 ===== ===== test accuracy is  0.988 ==========
# ========== 1140 ===== ===== test accuracy is  0.978 ==========
# ========== 1160 ===== ===== test accuracy is  0.982 ==========
# ========== 1180 ===== ===== test accuracy is  0.984 ==========
